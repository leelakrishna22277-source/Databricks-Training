# %%
df = spark.read.csv(
    "/Volumes/workspace/default/first_volume/empData.csv",
    header=True,
    inferSchema=True
)

# %%
df.show()
# Out:
# +------+------+------+-------+
# |emp_id|  name|salary|address|
# +------+------+------+-------+
# |     1|manish| 10000|  india|
# |     2|  rani| 20000|    usa|
# |     3| rinku| 55000|     uk|
# |     4|  neha| 12000|    usa|
# |     5| sneha| 20000|     uk|
# |     6| rahul| 30000|  india|
# +------+------+------+-------+

# %%
df.write.mode("overwrite").saveAsTable("employees")

# %%
df1 = spark.read.csv(
    "/Volumes/workspace/default/first_volume/Big Sales.csv",
    header=True,
    inferSchema=True
)

#header=True ----->>> becomes proper column names.
# inferSchema=true

# Without inferschema=true: all columns become STRING

# With inferSchema=true: numbers become INT, dates become DATE
df1.show()
# Out:
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-----------+--------------------+-----------------+-----------------+
# |Item_Identifier|Item_Weight|Item_Fat_Content|Item_Visibility|           Item_Type|Item_MRP|Outlet_Identifier|Outlet_Establishment_Year|Outlet_Size|Outlet_Location_Type|      Outlet_Type|Item_Outlet_Sales|
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-----------+--------------------+-----------------+-----------------+
# |          FDA15|        9.3|         Low Fat|    0.016047301|               Dairy|249.8092|           OUT049|                     1999|     Medium|              Tier 1|Supermarket Type1|         3735.138|
# ...
